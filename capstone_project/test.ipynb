# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3

# %%
con = sqlite3.connect('archive/nba.sqlite')
cur = con.cursor()

# %%
df = pd.read_sql_query("SELECT * from play_by_play WHERE game_id = '0022200755'", con)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_id                    474 non-null    object
#  1   eventnum                   474 non-null    int64
#  2   eventmsgtype               474 non-null    int64
#  3   eventmsgactiontype         474 non-null    int64
#  4   period                     474 non-null    int64
#  5   wctimestring               474 non-null    object
#  6   pctimestring               474 non-null    object
#  7   homedescription            257 non-null    object
#  8   neutraldescription         8 non-null      object
#  9   visitordescription         230 non-null    object
#  10  score                      128 non-null    object
#  11  scoremargin                128 non-null    object
#  12  person1type                474 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
df[['eventnum', 'eventmsgtype', 'eventmsgactiontype', 'score', 'homedescription', 'neutraldescription', 'visitordescription']]
# Out:
#      eventnum  eventmsgtype  eventmsgactiontype      score  \
# 0           2            12                   0       None
# 1           4            10                   0       None
# 2           7             2                   1       None
# 3           8             4                   0       None
# 4           9             6                   2       None
# 5          11             3                  11      0 - 1
# 6          12             3                  12       None
# 7          13             4                   0       None
# 8          14             2                 103       None
# 9          15             4                   0       None
# 10         16             1                  52      0 - 3
# 11         18             5                  40       None
# 12         20             1                 108      0 - 5
# 13         23             2                   1       None
# 14         24             4                   0       None
# ...
