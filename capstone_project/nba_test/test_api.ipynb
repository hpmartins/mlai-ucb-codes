# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
career.get_json()

# dictionary
career.get_dict()
# Out:
# {'resource': 'playercareerstats',
#  'parameters': {'PerMode': 'Totals', 'PlayerID': 203999, 'LeagueID': None},
#  'resultSets': [{'name': 'SeasonTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '2015-16',
#      '00',
#      1610612743,
#      'DEN',
#      21.0,
#      80,
#      55,
#      1733.0,
#      307,
#      600,
#      0.512,
#      28,
#      84,
#      0.333,
#      154,
#      190,
#      0.811,
#      181,
#      379,
#      560,
#      189,
#      79,
#      50,
#      104,
#      208,
#      796],
#     [203999,
#      '2016-17',
#      '00',
# ...

# %%
from nba_api.stats.endpoints import playbyplayv3

# %%
test = playbyplayv3.PlayByPlayV3(game_id = '0022300274')

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)

# %%
test.get_data_frames()[0]
# Out:
#          gameId  actionNumber        clock  period      teamId teamTricode  \
# 0    0022300274             2  PT12M00.00S       1           0
# 1    0022300274             4  PT12M00.00S       1  1610612753         ORL
# 2    0022300274             7  PT11M34.00S       1  1610612764         WAS
# 3    0022300274             9  PT11M13.00S       1  1610612753         ORL
# 4    0022300274            11  PT10M58.00S       1  1610612753         ORL
# ..          ...           ...          ...     ...         ...         ...
# 523  0022300274           723  PT00M06.00S       4  1610612764         WAS
# 524  0022300274           725  PT00M06.00S       4  1610612753         ORL
# 525  0022300274           726  PT00M06.00S       4  1610612753         ORL
# 526  0022300274           727  PT00M00.20S       4  1610612764         WAS
# 527  0022300274           728  PT00M00.00S       4           0
#
#      personId playerName   playerNameI  xLegacy  yLegacy  shotDistance  \
# ...

# %%
from nba_api.stats.endpoints import teamgamelogs


test = teamgamelogs.TeamGameLogs(team_id_nullable=1610612744, season_nullable='2018-19', season_type_nullable='Playoffs')

# %%
df = test.get_data_frames()[0]
df
# Out:
#    SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0      2018-19  1610612744               GSW  Golden State Warriors
# 1      2018-19  1610612744               GSW  Golden State Warriors
# 2      2018-19  1610612744               GSW  Golden State Warriors
# 3      2018-19  1610612744               GSW  Golden State Warriors
# 4      2018-19  1610612744               GSW  Golden State Warriors
# 5      2018-19  1610612744               GSW  Golden State Warriors
# 6      2018-19  1610612744               GSW  Golden State Warriors
# 7      2018-19  1610612744               GSW  Golden State Warriors
# 8      2018-19  1610612744               GSW  Golden State Warriors
# 9      2018-19  1610612744               GSW  Golden State Warriors
# 10     2018-19  1610612744               GSW  Golden State Warriors
# 11     2018-19  1610612744               GSW  Golden State Warriors
# 12     2018-19  1610612744               GSW  Golden State Warriors
# ...

# %%
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        2016-17  1610612750               MIN  Minnesota Timberwolves
# 1        2016-17  1610612744               GSW   Golden State Warriors
# 2        2016-17  1610612760               OKC   Oklahoma City Thunder
# 3        2016-17  1610612745               HOU         Houston Rockets
# 4        2016-17  1610612754               IND          Indiana Pacers
# ...          ...         ...               ...                     ...
# 2455     2016-17  1610612762               UTA               Utah Jazz
# 2456     2016-17  1610612752               NYK         New York Knicks
# 2457     2016-17  1610612744               GSW   Golden State Warriors
# 2458     2016-17  1610612759               SAS       San Antonio Spurs
# 2459     2016-17  1610612739               CLE     Cleveland Cavaliers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  FGA  FG_PCT  \
# ...
